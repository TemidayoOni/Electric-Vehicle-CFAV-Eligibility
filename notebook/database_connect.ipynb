# %%
import pandas as pd

import os
import pymongo
from pymongo.errors import AutoReconnect
import time
from dotenv import load_dotenv

# %%
EV_df = pd.read_csv("Electric_Vehicle_Population_Data.csv")
EV_df.head(10)
# Out:
#    VIN (1-10)     County               City State  Postal Code  Model Year  \
# 0  5YJSA1E65N     Yakima            Granger    WA      98932.0        2022
# 1  KNDC3DLC5N     Yakima             Yakima    WA      98902.0        2022
# 2  5YJYGDEEXL  Snohomish            Everett    WA      98208.0        2020
# 3  3C3CFFGE1G     Yakima             Yakima    WA      98908.0        2016
# 4  KNDCC3LD5K     Kitsap          Bremerton    WA      98312.0        2019
# 5  5YJXCAE29L     Kitsap         Silverdale    WA      98383.0        2020
# 6  5YJ3E1EB6L       King               Kent    WA      98030.0        2020
# 7  JTDKN3DP9F     Kitsap  Bainbridge Island    WA      98110.0        2015
# 8  1G1FY6S07L     Kitsap       Port Orchard    WA      98367.0        2020
# 9  1G1RD6S55K     Yakima             Yakima    WA      98908.0        2019
#
#         Make    Model                   Electric Vehicle Type  \
# 0      TESLA  MODEL S          Battery Electric Vehicle (BEV)
# 1        KIA      EV6          Battery Electric Vehicle (BEV)
# 2      TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 3       FIAT      500          Battery Electric Vehicle (BEV)
# 4        KIA     NIRO  Plug-in Hybrid Electric Vehicle (PHEV)
# 5      TESLA  MODEL X          Battery Electric Vehicle (BEV)
# 6      TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 7     TOYOTA    PRIUS  Plug-in Hybrid Electric Vehicle (PHEV)
# 8  CHEVROLET  BOLT EV          Battery Electric Vehicle (BEV)
# 9  CHEVROLET     VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0  Eligibility unknown as battery range has not b...             0.0
# 1  Eligibility unknown as battery range has not b...             0.0
# 2            Clean Alternative Fuel Vehicle Eligible           291.0
# 3            Clean Alternative Fuel Vehicle Eligible            84.0
# 4              Not eligible due to low battery range            26.0
# 5            Clean Alternative Fuel Vehicle Eligible           293.0
# 6            Clean Alternative Fuel Vehicle Eligible           322.0
# 7              Not eligible due to low battery range             6.0
# 8            Clean Alternative Fuel Vehicle Eligible           259.0
# 9            Clean Alternative Fuel Vehicle Eligible            53.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  15.0       187279214
# 1        0.0                  15.0       210098241
# 2        0.0                  44.0       121781950
# 3        0.0                  14.0       180778377
# 4        0.0                  26.0         2581225
# 5        0.0                  23.0         1843054
# 6        0.0                  47.0       182822020
# 7        0.0                  23.0       177904170
# 8        0.0                  26.0       132558002
# 9        0.0                  14.0       474853417
#
#               Vehicle Location                               Electric Utility  \
# 0   POINT (-120.1871 46.33949)                                     PACIFICORP
# 1  POINT (-120.52041 46.59751)                                     PACIFICORP
# 2  POINT (-122.18637 47.89251)                         PUGET SOUND ENERGY INC
# 3  POINT (-120.60199 46.59817)                                     PACIFICORP
# 4  POINT (-122.65223 47.57192)                         PUGET SOUND ENERGY INC
# 5  POINT (-122.69275 47.65171)                         PUGET SOUND ENERGY INC
# 6  POINT (-122.19975 47.37483)  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 7    POINT (-122.521 47.62732)                         PUGET SOUND ENERGY INC
# 8  POINT (-122.68471 47.50524)                         PUGET SOUND ENERGY INC
# 9  POINT (-120.60199 46.59817)                                     PACIFICORP
#
#    2020 Census Tract
# 0       5.307700e+10
# 1       5.307700e+10
# 2       5.306104e+10
# 3       5.307700e+10
# 4       5.303508e+10
# 5       5.303509e+10
# 6       5.303303e+10
# 7       5.303509e+10
# 8       5.303509e+10
# 9       5.307700e+10

# %%
EV_df.shape
# Out:
# (250659, 17)

# %%
EV_df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
EV_data = EV_df.to_dict(orient="records")
EV_data
# Out:
# [{'VIN (1-10)': '5YJSA1E65N',
#   'County': 'Yakima',
#   'City': 'Granger',
#   'State': 'WA',
#   'Postal Code': 98932.0,
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'MODEL S',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 15.0,
#   'DOL Vehicle ID': 187279214,
#   'Vehicle Location': 'POINT (-120.1871 46.33949)',
#   'Electric Utility': 'PACIFICORP',
#   '2020 Census Tract': 53077002104.0},
#  {'VIN (1-10)': 'KNDC3DLC5N',
#   'County': 'Yakima',
#   'City': 'Yakima',
#   'State': 'WA',
#   'Postal Code': 98902.0,
#   'Model Year': 2022,
#   'Make': 'KIA',
#   'Model': 'EV6',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 15.0,
#   'DOL Vehicle ID': 210098241,
#   'Vehicle Location': 'POINT (-120.52041 46.59751)',
#   'Electric Utility': 'PACIFICORP',
#   '2020 Census Tract': 53077001100.0},
#  {'VIN (1-10)': '5YJYGDEEXL',
#   'County': 'Snohomish',
#   'City': 'Everett',
#   'State': 'WA',
#   'Postal Code': 98208.0,
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'MODEL Y',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 291.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 44.0,
#   'DOL Vehicle ID': 121781950,
#   'Vehicle Location': 'POINT (-122.18637 47.89251)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061041610.0},
#  {'VIN (1-10)': '3C3CFFGE1G',
#   'County': 'Yakima',
#   'City': 'Yakima',
#   'State': 'WA',
#   'Postal Code': 98908.0,
#   'Model Year': 2016,
#   'Make': 'FIAT',
#   'Model': '500',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 84.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 14.0,
#   'DOL Vehicle ID': 180778377,
#   'Vehicle Location': 'POINT (-120.60199 46.59817)',
#   'Electric Utility': 'PACIFICORP',
#   '2020 Census Tract': 53077000401.0},
#  {'VIN (1-10)': 'KNDCC3LD5K',
#   'County': 'Kitsap',
#   'City': 'Bremerton',
#   'State': 'WA',
#   'Postal Code': 98312.0,
#   'Model Year': 2019,
#   'Make': 'KIA',
#   'Model': 'NIRO',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 26.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 26.0,
#   'DOL Vehicle ID': 2581225,
#   'Vehicle Location': 'POINT (-122.65223 47.57192)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035080600.0},
#  {'VIN (1-10)': '5YJXCAE29L',
#   'County': 'Kitsap',
#   'City': 'Silverdale',
#   'State': 'WA',
#   'Postal Code': 98383.0,
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'MODEL X',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 293.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 1843054,
#   'Vehicle Location': 'POINT (-122.69275 47.65171)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035091206.0},
#  {'VIN (1-10)': '5YJ3E1EB6L',
#   'County': 'King',
#   'City': 'Kent',
#   'State': 'WA',
#   'Postal Code': 98030.0,
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 322.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 47.0,
#   'DOL Vehicle ID': 182822020,
#   'Vehicle Location': 'POINT (-122.19975 47.37483)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033029602.0},
#  {'VIN (1-10)': 'JTDKN3DP9F',
#   'County': 'Kitsap',
#   'City': 'Bainbridge Island',
#   'State': 'WA',
#   'Postal Code': 98110.0,
#   'Model Year': 2015,
#   'Make': 'TOYOTA',
#   'Model': 'PRIUS',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 6.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 177904170,
#   'Vehicle Location': 'POINT (-122.521 47.62732)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035090700.0},
#  {'VIN (1-10)': '1G1FY6S07L',
#   'County': 'Kitsap',
#   'City': 'Port Orchard',
#   'State': 'WA',
#   'Postal Code': 98367.0,
#   'Model Year': 2020,
#   'Make': 'CHEVROLET',
#   'Model': 'BOLT EV',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 259.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 26.0,
#   'DOL Vehicle ID': 132558002,
#   'Vehicle Location': 'POINT (-122.68471 47.50524)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035092802.0},
#  {'VIN (1-10)': '1G1RD6S55K',
#   'County': 'Yakima',
#   'City': 'Yakima',
#   'State': 'WA',
#   'Postal Code': 98908.0,
#   'Model Year': 2019,
#   'Make': 'CHEVROLET',
#   'Model': 'VOLT',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 53.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 14.0,
#   'DOL Vehicle ID': 474853417,
#   'Vehicle Location': 'POINT (-120.60199 46.59817)',
#   'Electric Utility': 'PACIFICORP',
#   '2020 Census Tract': 53077002801.0},
#  {'VIN (1-10)': 'WA1VABGE7K',
#   'County': 'King',
#   'City': 'Shoreline',
#   'State': 'WA',
#   'Postal Code': 98133.0,
#   'Model Year': 2019,
#   'Make': 'AUDI',
#   'Model': 'E-TRON',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 204.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 32.0,
#   'DOL Vehicle ID': 252912397,
#   'Vehicle Location': 'POINT (-122.35029 47.71871)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033020700.0},
#  {'VIN (1-10)': '1N4AZ0CP1D',
#   'County': 'King',
#   'City': 'Seattle',
#   'State': 'WA',
#   'Postal Code': 98119.0,
#   'Model Year': 2013,
#   'Make': 'NISSAN',
#   'Model': 'LEAF',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 75.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 36.0,
#   'DOL Vehicle ID': 245254355,
#   'Vehicle Location': 'POINT (-122.3684 47.64586)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033006900.0},
#  {'VIN (1-10)': '4W5KHNRL1R',
#   'County': 'Snohomish',
#   'City': 'Bothell',
#   'State': 'WA',
#   'Postal Code': 98012.0,
#   'Model Year': 2024,
#   'Make': 'ACURA',
#   'Model': 'ZDX',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 21.0,
#   'DOL Vehicle ID': 277471652,
#   'Vehicle Location': 'POINT (-122.21061 47.83448)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061051927.0},
#  {'VIN (1-10)': '3MW39FF06P',
#   'County': 'Kitsap',
#   'City': 'Silverdale',
#   'State': 'WA',
#   'Postal Code': 98383.0,
#   'Model Year': 2023,
#   'Make': 'BMW',
#   'Model': '330E',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 22.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 259821229,
#   'Vehicle Location': 'POINT (-122.69275 47.65171)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035091205.0},
#  {'VIN (1-10)': 'WBY1Z6C37H',
#   'County': 'King',
#   'City': 'Seattle',
#   'State': 'WA',
#   'Postal Code': 98125.0,
#   'Model Year': 2017,
#   'Make': 'BMW',
#   'Model': 'I3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 81.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 46.0,
#   'DOL Vehicle ID': 282181980,
#   'Vehicle Location': 'POINT (-122.30253 47.72656)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033000700.0},
#  {'VIN (1-10)': '5YJ3E1EA2J',
#   'County': 'Snohomish',
#   'City': 'Everett',
#   'State': 'WA',
#   'Postal Code': 98204.0,
#   'Model Year': 2018,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 215.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 21.0,
#   'DOL Vehicle ID': 178546133,
#   'Vehicle Location': 'POINT (-122.27557 47.88936)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061041901.0},
#  {'VIN (1-10)': '5YJ3E1EA6L',
#   'County': 'King',
#   'City': 'Tukwila',
#   'State': 'WA',
#   'Postal Code': 98168.0,
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 266.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 11.0,
#   'DOL Vehicle ID': 102657789,
#   'Vehicle Location': 'POINT (-122.3317 47.50314)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033027200.0},
#  {'VIN (1-10)': '5YJ3E1EA4J',
#   'County': 'Kitsap',
#   'City': 'Poulsbo',
#   'State': 'WA',
#   'Postal Code': 98370.0,
#   'Model Year': 2018,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 215.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 474888991,
#   'Vehicle Location': 'POINT (-122.64681 47.73689)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035090201.0},
#  {'VIN (1-10)': '1FADP5CU0G',
#   'County': 'Kitsap',
#   'City': 'Kingston',
#   'State': 'WA',
#   'Postal Code': 98346.0,
#   'Model Year': 2016,
#   'Make': 'FORD',
#   'Model': 'C-MAX',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 19.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 1465033,
#   'Vehicle Location': 'POINT (-122.4977 47.79802)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035090102.0},
#  {'VIN (1-10)': '7FCTGAAA3P',
#   'County': 'Kitsap',
#   'City': 'Seabeck',
#   'State': 'WA',
#   'Postal Code': 98380.0,
#   'Model Year': 2023,
#   'Make': 'RIVIAN',
#   'Model': 'R1T',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 35.0,
#   'DOL Vehicle ID': 267014016,
#   'Vehicle Location': 'POINT (-122.81585 47.64509)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035091301.0},
#  {'VIN (1-10)': '1N4AZ0CP4D',
#   'County': 'Kitsap',
#   'City': 'Bremerton',
#   'State': 'WA',
#   'Postal Code': 98310.0,
#   'Model Year': 2013,
#   'Make': 'NISSAN',
#   'Model': 'LEAF',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 75.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 181560599,
#   'Vehicle Location': 'POINT (-122.61136 47.5752)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035080400.0},
#  {'VIN (1-10)': '1G1RD6E42E',
#   'County': 'Kitsap',
#   'City': 'Bremerton',
#   'State': 'WA',
#   'Postal Code': 98312.0,
#   'Model Year': 2014,
#   'Make': 'CHEVROLET',
#   'Model': 'VOLT',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 38.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 35.0,
#   'DOL Vehicle ID': 187081191,
#   'Vehicle Location': 'POINT (-122.65223 47.57192)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035080700.0},
#  {'VIN (1-10)': '5YJ3E1EB6J',
#   'County': 'Snohomish',
#   'City': 'Mukilteo',
#   'State': 'WA',
#   'Postal Code': 98275.0,
#   'Model Year': 2018,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 215.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 21.0,
#   'DOL Vehicle ID': 475060603,
#   'Vehicle Location': 'POINT (-122.29196 47.89908)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061042005.0},
#  {'VIN (1-10)': '1N4AZ0CP0D',
#   'County': 'King',
#   'City': 'Seattle',
#   'State': 'WA',
#   'Postal Code': 98125.0,
#   'Model Year': 2013,
#   'Make': 'NISSAN',
#   'Model': 'LEAF',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 75.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 46.0,
#   'DOL Vehicle ID': 211771696,
#   'Vehicle Location': 'POINT (-122.30253 47.72656)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033000900.0},
#  {'VIN (1-10)': '5YJ3E1EB2L',
#   'County': 'Yakima',
#   'City': 'Yakima',
#   'State': 'WA',
#   'Postal Code': 98902.0,
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 322.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 14.0,
#   'DOL Vehicle ID': 274036927,
#   'Vehicle Location': 'POINT (-120.52041 46.59751)',
#   'Electric Utility': 'PACIFICORP',
#   '2020 Census Tract': 53077000600.0},
#  {'VIN (1-10)': 'JM3KKBHA9R',
#   'County': 'Kitsap',
#   'City': 'Kingston',
#   'State': 'WA',
#   'Postal Code': 98346.0,
#   'Model Year': 2024,
#   'Make': 'MAZDA',
#   'Model': 'CX-90',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 26.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 275123642,
#   'Vehicle Location': 'POINT (-122.4977 47.79802)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035090102.0},
#  {'VIN (1-10)': '2C4RC1N72L',
#   'County': 'Snohomish',
#   'City': 'Mill Creek',
#   'State': 'WA',
#   'Postal Code': 98012.0,
#   'Model Year': 2020,
#   'Make': 'CHRYSLER',
#   'Model': 'PACIFICA',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 32.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 44.0,
#   'DOL Vehicle ID': 107651001,
#   'Vehicle Location': 'POINT (-122.21061 47.83448)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061052004.0},
#  {'VIN (1-10)': '7JRH60FW2P',
#   'County': 'Thurston',
#   'City': 'Yelm',
#   'State': 'WA',
#   'Postal Code': 98597.0,
#   'Model Year': 2023,
#   'Make': 'VOLVO',
#   'Model': 'S60',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 41.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 2.0,
#   'DOL Vehicle ID': 275696725,
#   'Vehicle Location': 'POINT (-122.60735 46.94239)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067012532.0},
#  {'VIN (1-10)': '5YJSA1E25K',
#   'County': 'King',
#   'City': 'Kent',
#   'State': 'WA',
#   'Postal Code': 98042.0,
#   'Model Year': 2019,
#   'Make': 'TESLA',
#   'Model': 'MODEL S',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 270.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 47.0,
#   'DOL Vehicle ID': 214922046,
#   'Vehicle Location': 'POINT (-122.09124 47.33778)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033031707.0},
#  {'VIN (1-10)': 'WP0CK2A78N',
#   'County': 'Kitsap',
#   'City': 'Poulsbo',
#   'State': 'WA',
#   'Postal Code': 98370.0,
#   'Model Year': 2022,
#   'Make': 'PORSCHE',
#   'Model': 'PANAMERA',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 18.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 193230292,
#   'Vehicle Location': 'POINT (-122.64681 47.73689)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035940100.0},
#  {'VIN (1-10)': '7FCTGBAA0P',
#   'County': 'Kitsap',
#   'City': 'Kingston',
#   'State': 'WA',
#   'Postal Code': 98346.0,
#   'Model Year': 2023,
#   'Make': 'RIVIAN',
#   'Model': 'R1T',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 271119152,
#   'Vehicle Location': 'POINT (-122.4977 47.79802)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035090102.0},
#  {'VIN (1-10)': '5YJSA1E18G',
#   'County': 'Yakima',
#   'City': 'Toppenish',
#   'State': 'WA',
#   'Postal Code': 98948.0,
#   'Model Year': 2016,
#   'Make': 'TESLA',
#   'Model': 'MODEL S',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 210.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 15.0,
#   'DOL Vehicle ID': 477474546,
#   'Vehicle Location': 'POINT (-120.31298 46.37508)',
#   'Electric Utility': 'PACIFICORP',
#   '2020 Census Tract': 53077940006.0},
#  {'VIN (1-10)': '5YJSA1E29J',
#   'County': 'Thurston',
#   'City': 'Olympia',
#   'State': 'WA',
#   'Postal Code': 98502.0,
#   'Model Year': 2018,
#   'Make': 'TESLA',
#   'Model': 'MODEL S',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 249.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 22.0,
#   'DOL Vehicle ID': 211037095,
#   'Vehicle Location': 'POINT (-122.92333 47.03779)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067011100.0},
#  {'VIN (1-10)': '1N4BZ0CP6G',
#   'County': 'King',
#   'City': 'Seattle',
#   'State': 'WA',
#   'Postal Code': 98125.0,
#   'Model Year': 2016,
#   'Make': 'NISSAN',
#   'Model': 'LEAF',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 84.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 46.0,
#   'DOL Vehicle ID': 348134671,
#   'Vehicle Location': 'POINT (-122.30253 47.72656)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033000202.0},
#  {'VIN (1-10)': '5YJ3E1EA0P',
#   'County': 'Thurston',
#   'City': 'Olympia',
#   'State': 'WA',
#   'Postal Code': 98501.0,
#   'Model Year': 2023,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 22.0,
#   'DOL Vehicle ID': 262104433,
#   'Vehicle Location': 'POINT (-122.89165 47.03954)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067010300.0},
#  {'VIN (1-10)': '1FADP5CU8G',
#   'County': 'Thurston',
#   'City': 'Rainier',
#   'State': 'WA',
#   'Postal Code': 98576.0,
#   'Model Year': 2016,
#   'Make': 'FORD',
#   'Model': 'C-MAX',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 19.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 2.0,
#   'DOL Vehicle ID': 477478004,
#   'Vehicle Location': 'POINT (-122.68993 46.88897)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067012531.0},
#  {'VIN (1-10)': '1FADP5CU3D',
#   'County': 'Thurston',
#   'City': 'Yelm',
#   'State': 'WA',
#   'Postal Code': 98597.0,
#   'Model Year': 2013,
#   'Make': 'FORD',
#   'Model': 'C-MAX',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 19.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 2.0,
#   'DOL Vehicle ID': 230136070,
#   'Vehicle Location': 'POINT (-122.60735 46.94239)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067012531.0},
#  {'VIN (1-10)': '5YJ3E1EB9N',
#   'County': 'Thurston',
#   'City': 'Yelm',
#   'State': 'WA',
#   'Postal Code': 98597.0,
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 2.0,
#   'DOL Vehicle ID': 203361805,
#   'Vehicle Location': 'POINT (-122.60735 46.94239)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067012422.0},
#  {'VIN (1-10)': '3C3CFFGE0G',
#   'County': 'Thurston',
#   'City': 'Olympia',
#   'State': 'WA',
#   'Postal Code': 98506.0,
#   'Model Year': 2016,
#   'Make': 'FIAT',
#   'Model': '500',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 84.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 22.0,
#   'DOL Vehicle ID': 194169839,
#   'Vehicle Location': 'POINT (-122.87741 47.05997)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067010300.0},
#  {'VIN (1-10)': '3FA6P0SU7F',
#   'County': 'Thurston',
#   'City': 'Yelm',
#   'State': 'WA',
#   'Postal Code': 98597.0,
#   'Model Year': 2015,
#   'Make': 'FORD',
#   'Model': 'FUSION',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 19.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 2.0,
#   'DOL Vehicle ID': 257376094,
#   'Vehicle Location': 'POINT (-122.60735 46.94239)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067012412.0},
#  {'VIN (1-10)': 'KNDPZDDH8R',
#   'County': 'Thurston',
#   'City': 'Yelm',
#   'State': 'WA',
#   'Postal Code': 98597.0,
#   'Model Year': 2024,
#   'Make': 'KIA',
#   'Model': 'SPORTAGE',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 34.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 2.0,
#   'DOL Vehicle ID': 261672442,
#   'Vehicle Location': 'POINT (-122.60735 46.94239)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067012422.0},
#  {'VIN (1-10)': '5YJSA1E22K',
#   'County': 'King',
#   'City': 'Seattle',
#   'State': 'WA',
#   'Postal Code': 98112.0,
#   'Model Year': 2019,
#   'Make': 'TESLA',
#   'Model': 'MODEL S',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 270.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 43.0,
#   'DOL Vehicle ID': 202233958,
#   'Vehicle Location': 'POINT (-122.30207 47.64085)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033006500.0},
#  {'VIN (1-10)': '5YJSA1E20G',
#   'County': 'Snohomish',
#   'City': 'Edmonds',
#   'State': 'WA',
#   'Postal Code': 98026.0,
#   'Model Year': 2016,
#   'Make': 'TESLA',
#   'Model': 'MODEL S',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 210.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 21.0,
#   'DOL Vehicle ID': 128793731,
#   'Vehicle Location': 'POINT (-122.31768 47.87166)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061050200.0},
#  {'VIN (1-10)': '7SAYGDEE1R',
#   'County': 'Thurston',
#   'City': 'Yelm',
#   'State': 'WA',
#   'Postal Code': 98597.0,
#   'Model Year': 2024,
#   'Make': 'TESLA',
#   'Model': 'MODEL Y',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 2.0,
#   'DOL Vehicle ID': 263059128,
#   'Vehicle Location': 'POINT (-122.60735 46.94239)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067012422.0},
#  {'VIN (1-10)': '1N4AZ0CP8D',
#   'County': 'King',
#   'City': 'Shoreline',
#   'State': 'WA',
#   'Postal Code': 98133.0,
#   'Model Year': 2013,
#   'Make': 'NISSAN',
#   'Model': 'LEAF',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 75.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 32.0,
#   'DOL Vehicle ID': 221203671,
#   'Vehicle Location': 'POINT (-122.35029 47.71871)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033021000.0},
#  {'VIN (1-10)': 'YV4BR0DM9M',
#   'County': 'Kitsap',
#   'City': 'Port Orchard',
#   'State': 'WA',
#   'Postal Code': 98367.0,
#   'Model Year': 2021,
#   'Make': 'VOLVO',
#   'Model': 'XC60',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 18.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 26.0,
#   'DOL Vehicle ID': 135178102,
#   'Vehicle Location': 'POINT (-122.68471 47.50524)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035092902.0},
#  {'VIN (1-10)': '5YJ3E1EB0L',
#   'County': 'Yakima',
#   'City': 'Yakima',
#   'State': 'WA',
#   'Postal Code': 98901.0,
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 322.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 15.0,
#   'DOL Vehicle ID': 103028922,
#   'Vehicle Location': 'POINT (-120.50729 46.60464)',
#   'Electric Utility': 'PACIFICORP',
#   '2020 Census Tract': 53077001502.0},
#  {'VIN (1-10)': 'YV4BR0CK0M',
#   'County': 'Snohomish',
#   'City': 'Bothell',
#   'State': 'WA',
#   'Postal Code': 98012.0,
#   'Model Year': 2021,
#   'Make': 'VOLVO',
#   'Model': 'XC90',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 18.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 1.0,
#   'DOL Vehicle ID': 265947146,
#   'Vehicle Location': 'POINT (-122.21061 47.83448)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061052009.0},
#  {'VIN (1-10)': 'KNDCM3LD0L',
#   'County': 'Thurston',
#   'City': 'Olympia',
#   'State': 'WA',
#   'Postal Code': 98512.0,
#   'Model Year': 2020,
#   'Make': 'KIA',
#   'Model': 'NIRO',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 26.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 22.0,
#   'DOL Vehicle ID': 166160893,
#   'Vehicle Location': 'POINT (-122.9131 47.01359)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067011000.0},
#  {'VIN (1-10)': '5YJ3E1EB0L',
#   'County': 'King',
#   'City': 'Redmond',
#   'State': 'WA',
#   'Postal Code': 98052.0,
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 322.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 48.0,
#   'DOL Vehicle ID': 103695413,
#   'Vehicle Location': 'POINT (-122.13158 47.67858)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033032324.0},
#  {'VIN (1-10)': 'JN1AZ0CP2C',
#   'County': 'Kitsap',
#   'City': 'Silverdale',
#   'State': 'WA',
#   'Postal Code': 98383.0,
#   'Model Year': 2012,
#   'Make': 'NISSAN',
#   'Model': 'LEAF',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 73.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 120570271,
#   'Vehicle Location': 'POINT (-122.69275 47.65171)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035091206.0},
#  {'VIN (1-10)': '1G1RA6S50J',
#   'County': 'Thurston',
#   'City': 'Yelm',
#   'State': 'WA',
#   'Postal Code': 98597.0,
#   'Model Year': 2018,
#   'Make': 'CHEVROLET',
#   'Model': 'VOLT',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 53.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 20.0,
#   'DOL Vehicle ID': 476774427,
#   'Vehicle Location': 'POINT (-122.60735 46.94239)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067012531.0},
#  {'VIN (1-10)': '7FCTGAAA8N',
#   'County': 'Kitsap',
#   'City': 'Poulsbo',
#   'State': 'WA',
#   'Postal Code': 98370.0,
#   'Model Year': 2022,
#   'Make': 'RIVIAN',
#   'Model': 'R1T',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 227489762,
#   'Vehicle Location': 'POINT (-122.64681 47.73689)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035090400.0},
#  {'VIN (1-10)': 'KNDRMDLH1P',
#   'County': 'Kitsap',
#   'City': 'Port Orchard',
#   'State': 'WA',
#   'Postal Code': 98367.0,
#   'Model Year': 2023,
#   'Make': 'KIA',
#   'Model': 'SORENTO',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 32.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 26.0,
#   'DOL Vehicle ID': 255215635,
#   'Vehicle Location': 'POINT (-122.68471 47.50524)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035092902.0},
#  {'VIN (1-10)': 'WBY8P4C56K',
#   'County': 'Kitsap',
#   'City': 'Poulsbo',
#   'State': 'WA',
#   'Postal Code': 98370.0,
#   'Model Year': 2019,
#   'Make': 'BMW',
#   'Model': 'I3',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 126.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 276395647,
#   'Vehicle Location': 'POINT (-122.64681 47.73689)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035090501.0},
#  {'VIN (1-10)': 'LPSED3KA6M',
#   'County': 'Kitsap',
#   'City': 'Poulsbo',
#   'State': 'WA',
#   'Postal Code': 98370.0,
#   'Model Year': 2021,
#   'Make': 'POLESTAR',
#   'Model': 'PS2',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 233.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 186968694,
#   'Vehicle Location': 'POINT (-122.64681 47.73689)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035940100.0},
#  {'VIN (1-10)': '5UXTA6C07N',
#   'County': 'Snohomish',
#   'City': 'Lynnwood',
#   'State': 'WA',
#   'Postal Code': 98087.0,
#   'Model Year': 2022,
#   'Make': 'BMW',
#   'Model': 'X5',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 30.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 21.0,
#   'DOL Vehicle ID': 196269524,
#   'Vehicle Location': 'POINT (-122.27981 47.85727)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061041703.0},
#  {'VIN (1-10)': '5YJXCAE28G',
#   'County': 'Yakima',
#   'City': 'Yakima',
#   'State': 'WA',
#   'Postal Code': 98902.0,
#   'Model Year': 2016,
#   'Make': 'TESLA',
#   'Model': 'MODEL X',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 200.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 15.0,
#   'DOL Vehicle ID': 281450914,
#   'Vehicle Location': 'POINT (-120.52041 46.59751)',
#   'Electric Utility': 'PACIFICORP',
#   '2020 Census Tract': 53077001201.0},
#  {'VIN (1-10)': '1N4AZ0CP6F',
#   'County': 'King',
#   'City': 'Covington',
#   'State': 'WA',
#   'Postal Code': 98042.0,
#   'Model Year': 2015,
#   'Make': 'NISSAN',
#   'Model': 'LEAF',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 84.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 47.0,
#   'DOL Vehicle ID': 148012406,
#   'Vehicle Location': 'POINT (-122.09124 47.33778)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033032005.0},
#  {'VIN (1-10)': '7SAYGDEF2N',
#   'County': 'Snohomish',
#   'City': 'Bothell',
#   'State': 'WA',
#   'Postal Code': 98012.0,
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'MODEL Y',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 1.0,
#   'DOL Vehicle ID': 186545677,
#   'Vehicle Location': 'POINT (-122.21061 47.83448)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061052107.0},
#  {'VIN (1-10)': '3FA6P0SU3G',
#   'County': 'Snohomish',
#   'City': 'Lake Stevens',
#   'State': 'WA',
#   'Postal Code': 98258.0,
#   'Model Year': 2016,
#   'Make': 'FORD',
#   'Model': 'FUSION',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 19.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 44.0,
#   'DOL Vehicle ID': 478278958,
#   'Vehicle Location': 'POINT (-122.06402 48.01497)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061052504.0},
#  {'VIN (1-10)': '7SAYGDEE3R',
#   'County': 'Thurston',
#   'City': 'Yelm',
#   'State': 'WA',
#   'Postal Code': 98597.0,
#   'Model Year': 2024,
#   'Make': 'TESLA',
#   'Model': 'MODEL Y',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 20.0,
#   'DOL Vehicle ID': 269873691,
#   'Vehicle Location': 'POINT (-122.60735 46.94239)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067012510.0},
#  {'VIN (1-10)': '5YJSA1E29F',
#   'County': 'Snohomish',
#   'City': 'Arlington',
#   'State': 'WA',
#   'Postal Code': 98223.0,
#   'Model Year': 2015,
#   'Make': 'TESLA',
#   'Model': 'MODEL S',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 208.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 39.0,
#   'DOL Vehicle ID': 166232902,
#   'Vehicle Location': 'POINT (-122.1264 48.19471)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061053507.0},
#  {'VIN (1-10)': '1N4BZ1CP6K',
#   'County': 'Kitsap',
#   'City': 'Poulsbo',
#   'State': 'WA',
#   'Postal Code': 98370.0,
#   'Model Year': 2019,
#   'Make': 'NISSAN',
#   'Model': 'LEAF',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 150.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 4742531,
#   'Vehicle Location': 'POINT (-122.64681 47.73689)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035090502.0},
#  {'VIN (1-10)': '5YJ3E1EB1L',
#   'County': 'Thurston',
#   'City': 'Tumwater',
#   'State': 'WA',
#   'Postal Code': 98512.0,
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 322.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 22.0,
#   'DOL Vehicle ID': 8013113,
#   'Vehicle Location': 'POINT (-122.9131 47.01359)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067010910.0},
#  {'VIN (1-10)': '1N4BZ1DV9M',
#   'County': 'Kitsap',
#   'City': 'Bremerton',
#   'State': 'WA',
#   'Postal Code': 98337.0,
#   'Model Year': 2021,
#   'Make': 'NISSAN',
#   'Model': 'LEAF',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 26.0,
#   'DOL Vehicle ID': 152421370,
#   'Vehicle Location': 'POINT (-122.62749 47.565)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035081200.0},
#  {'VIN (1-10)': '5YJ3E1EB1J',
#   'County': 'Kitsap',
#   'City': 'Poulsbo',
#   'State': 'WA',
#   'Postal Code': 98370.0,
#   'Model Year': 2018,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 215.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 124514484,
#   'Vehicle Location': 'POINT (-122.64681 47.73689)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035090202.0},
#  {'VIN (1-10)': '5YJ3E1EAXJ',
#   'County': 'King',
#   'City': 'Seattle',
#   'State': 'WA',
#   'Postal Code': 98144.0,
#   'Model Year': 2018,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 215.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 37.0,
#   'DOL Vehicle ID': 138452401,
#   'Vehicle Location': 'POINT (-122.30866 47.57874)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033009500.0},
#  {'VIN (1-10)': '1C4RJYE62P',
#   'County': 'Kitsap',
#   'City': 'Poulsbo',
#   'State': 'WA',
#   'Postal Code': 98370.0,
#   'Model Year': 2023,
#   'Make': 'JEEP',
#   'Model': 'GRAND CHEROKEE',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 25.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 277080163,
#   'Vehicle Location': 'POINT (-122.64681 47.73689)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035090501.0},
#  {'VIN (1-10)': '7FCTGAAL7N',
#   'County': 'Kitsap',
#   'City': 'Poulsbo',
#   'State': 'WA',
#   'Postal Code': 98370.0,
#   'Model Year': 2022,
#   'Make': 'RIVIAN',
#   'Model': 'R1T',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 208663031,
#   'Vehicle Location': 'POINT (-122.64681 47.73689)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035090202.0},
#  {'VIN (1-10)': '5YJYGDEE5M',
#   'County': 'Kitsap',
#   'City': 'Suquamish',
#   'State': 'WA',
#   'Postal Code': 98392.0,
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'MODEL Y',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 23.0,
#   'DOL Vehicle ID': 205138552,
#   'Vehicle Location': 'POINT (-122.55242 47.73162)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53035940100.0},
#  {'VIN (1-10)': 'KNDCC3LD7N',
#   'County': 'Snohomish',
#   'City': 'Bothell',
#   'State': 'WA',
#   'Postal Code': 98012.0,
#   'Model Year': 2022,
#   'Make': 'KIA',
#   'Model': 'NIRO',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 26.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 1.0,
#   'DOL Vehicle ID': 194200681,
#   'Vehicle Location': 'POINT (-122.21061 47.83448)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061051936.0},
#  {'VIN (1-10)': '1N4AZ0CPXD',
#   'County': 'Thurston',
#   'City': 'Olympia',
#   'State': 'WA',
#   'Postal Code': 98501.0,
#   'Model Year': 2013,
#   'Make': 'NISSAN',
#   'Model': 'LEAF',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 75.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 22.0,
#   'DOL Vehicle ID': 5617937,
#   'Vehicle Location': 'POINT (-122.89165 47.03954)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067010100.0},
#  {'VIN (1-10)': '5YJSA1DP4D',
#   'County': 'Yakima',
#   'City': 'Zillah',
#   'State': 'WA',
#   'Postal Code': 98953.0,
#   'Model Year': 2013,
#   'Make': 'TESLA',
#   'Model': 'MODEL S',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 208.0,
#   'Base MSRP': 69900.0,
#   'Legislative District': 15.0,
#   'DOL Vehicle ID': 161861780,
#   'Vehicle Location': 'POINT (-120.26226 46.40199)',
#   'Electric Utility': 'PACIFICORP',
#   '2020 Census Tract': 53077002201.0},
#  {'VIN (1-10)': '5YJSA1E24L',
#   'County': 'King',
#   'City': 'Sammamish',
#   'State': 'WA',
#   'Postal Code': 98075.0,
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'MODEL S',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 330.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 41.0,
#   'DOL Vehicle ID': 5013942,
#   'Vehicle Location': 'POINT (-122.03539 47.61344)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033032217.0},
#  {'VIN (1-10)': '5YJ3E1EA0K',
#   'County': 'Snohomish',
#   'City': 'Bothell',
#   'State': 'WA',
#   'Postal Code': 98012.0,
#   'Model Year': 2019,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 220.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 1.0,
#   'DOL Vehicle ID': 477457774,
#   'Vehicle Location': 'POINT (-122.21061 47.83448)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061052107.0},
#  {'VIN (1-10)': '5YJ3E1EB9J',
#   'County': 'Island',
#   'City': 'Oak Harbor',
#   'State': 'WA',
#   'Postal Code': 98277.0,
#   'Model Year': 2018,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 215.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 10.0,
#   'DOL Vehicle ID': 282291271,
#   'Vehicle Location': 'POINT (-122.64682 48.29077)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53029970401.0},
#  {'VIN (1-10)': '1N4AZ0CPXF',
#   'County': 'King',
#   'City': 'Des Moines',
#   'State': 'WA',
#   'Postal Code': 98198.0,
#   'Model Year': 2015,
#   'Make': 'NISSAN',
#   'Model': 'LEAF',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 84.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 33.0,
#   'DOL Vehicle ID': 6578344,
#   'Vehicle Location': 'POINT (-122.3219 47.40173)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033028901.0},
#  {'VIN (1-10)': '5UXKT0C51G',
#   'County': 'King',
#   'City': 'Seattle',
#   'State': 'WA',
#   'Postal Code': 98199.0,
#   'Model Year': 2016,
#   'Make': 'BMW',
#   'Model': 'X5',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 14.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 36.0,
#   'DOL Vehicle ID': 150463022,
#   'Vehicle Location': 'POINT (-122.40092 47.65908)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033005600.0},
#  {'VIN (1-10)': 'WA1F2AFY2R',
#   'County': 'Snohomish',
#   'City': 'Bothell',
#   'State': 'WA',
#   'Postal Code': 98021.0,
#   'Model Year': 2024,
#   'Make': 'AUDI',
#   'Model': 'Q5 E',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 23.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 1.0,
#   'DOL Vehicle ID': 276998613,
#   'Vehicle Location': 'POINT (-122.18384 47.8031)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061051937.0},
#  {'VIN (1-10)': '1N4BZ1CP8L',
#   'County': 'King',
#   'City': 'Burien',
#   'State': 'WA',
#   'Postal Code': 98166.0,
#   'Model Year': 2020,
#   'Make': 'NISSAN',
#   'Model': 'LEAF',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 215.0,
#   'Base MSRP': 0.0,
# ...
#   'Model Year': 2025,
#   'Make': 'RIVIAN',
#   'Model': 'R1S',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 48.0,
#   'DOL Vehicle ID': 272270624,
#   'Vehicle Location': 'POINT (-122.2066 47.67887)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033022501.0},
#  {'VIN (1-10)': '3C3CFFGE1E',
#   'County': 'King',
#   'City': 'Kirkland',
#   'State': 'WA',
#   'Postal Code': 98033.0,
#   'Model Year': 2014,
#   'Make': 'FIAT',
#   'Model': '500',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 87.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 48.0,
#   'DOL Vehicle ID': 6348352,
#   'Vehicle Location': 'POINT (-122.2066 47.67887)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033022603.0},
#  {'VIN (1-10)': 'WB523CF08R',
#   'County': 'Clark',
#   'City': 'Vancouver',
#   'State': 'WA',
#   'Postal Code': 98682.0,
#   'Model Year': 2024,
#   'Make': 'BMW',
#   'Model': 'IX',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 17.0,
#   'DOL Vehicle ID': 258243982,
#   'Vehicle Location': 'POINT (-122.55149 45.69345)',
#   'Electric Utility': 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)',
#   '2020 Census Tract': 53011041312.0},
#  {'VIN (1-10)': '7SAYGAEE9N',
#   'County': 'King',
#   'City': 'Federal Way',
#   'State': 'WA',
#   'Postal Code': 98003.0,
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'MODEL Y',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 30.0,
#   'DOL Vehicle ID': 183326195,
#   'Vehicle Location': 'POINT (-122.3303 47.30151)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033030102.0},
#  {'VIN (1-10)': '5YJYGDEE3M',
#   'County': 'Thurston',
#   'City': 'Olympia',
#   'State': 'WA',
#   'Postal Code': 98506.0,
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'MODEL Y',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 22.0,
#   'DOL Vehicle ID': 179091426,
#   'Vehicle Location': 'POINT (-122.87741 47.05997)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53067010200.0},
#  {'VIN (1-10)': 'KNDC34LAXP',
#   'County': 'King',
#   'City': 'Seattle',
#   'State': 'WA',
#   'Postal Code': 98133.0,
#   'Model Year': 2023,
#   'Make': 'KIA',
#   'Model': 'EV6',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 46.0,
#   'DOL Vehicle ID': 265561292,
#   'Vehicle Location': 'POINT (-122.35029 47.71871)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033000601.0},
#  {'VIN (1-10)': '3C3CFFGE6F',
#   'County': 'King',
#   'City': 'Seattle',
#   'State': 'WA',
#   'Postal Code': 98125.0,
#   'Model Year': 2015,
#   'Make': 'FIAT',
#   'Model': '500',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 87.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 46.0,
#   'DOL Vehicle ID': 114138384,
#   'Vehicle Location': 'POINT (-122.30253 47.72656)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033000102.0},
#  {'VIN (1-10)': '2C4RC1L72P',
#   'County': 'King',
#   'City': 'Kent',
#   'State': 'WA',
#   'Postal Code': 98030.0,
#   'Model Year': 2023,
#   'Make': 'CHRYSLER',
#   'Model': 'PACIFICA',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 32.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 47.0,
#   'DOL Vehicle ID': 267054588,
#   'Vehicle Location': 'POINT (-122.19975 47.37483)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033029507.0},
#  {'VIN (1-10)': '5YJYGDEE5M',
#   'County': 'King',
#   'City': 'Kirkland',
#   'State': 'WA',
#   'Postal Code': 98033.0,
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'MODEL Y',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 45.0,
#   'DOL Vehicle ID': 280895807,
#   'Vehicle Location': 'POINT (-122.2066 47.67887)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033022401.0},
#  {'VIN (1-10)': '1N4AZ1CV8N',
#   'County': 'King',
#   'City': 'Bellevue',
#   'State': 'WA',
#   'Postal Code': 98007.0,
#   'Model Year': 2022,
#   'Make': 'NISSAN',
#   'Model': 'LEAF',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 41.0,
#   'DOL Vehicle ID': 185993699,
#   'Vehicle Location': 'POINT (-122.12056 47.61334)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033023604.0},
#  {'VIN (1-10)': '7SAYGDEE0S',
#   'County': 'King',
#   'City': 'Bellevue',
#   'State': 'WA',
#   'Postal Code': 98004.0,
#   'Model Year': 2025,
#   'Make': 'TESLA',
#   'Model': 'MODEL Y',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 41.0,
#   'DOL Vehicle ID': 273258268,
#   'Vehicle Location': 'POINT (-122.1872 47.61001)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033023901.0},
#  {'VIN (1-10)': '7SAYGDEEXP',
#   'County': 'King',
#   'City': 'Bothell',
#   'State': 'WA',
#   'Postal Code': 98011.0,
#   'Model Year': 2023,
#   'Make': 'TESLA',
#   'Model': 'MODEL Y',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 1.0,
#   'DOL Vehicle ID': 256223978,
#   'Vehicle Location': 'POINT (-122.20563 47.76144)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033021804.0},
#  {'VIN (1-10)': '5YJ3E1EC4N',
#   'County': 'King',
#   'City': 'Seattle',
#   'State': 'WA',
#   'Postal Code': 98146.0,
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 34.0,
#   'DOL Vehicle ID': 192270683,
#   'Vehicle Location': 'POINT (-122.36178 47.49408)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033012000.0},
#  {'VIN (1-10)': '5YJXCAE2XH',
#   'County': 'King',
#   'City': 'Sammamish',
#   'State': 'WA',
#   'Postal Code': 98075.0,
#   'Model Year': 2017,
#   'Make': 'TESLA',
#   'Model': 'MODEL X',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 200.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 41.0,
#   'DOL Vehicle ID': 304527541,
#   'Vehicle Location': 'POINT (-122.03539 47.61344)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033032215.0},
#  {'VIN (1-10)': '5YJ3E1EA9P',
#   'County': 'King',
#   'City': 'Renton',
#   'State': 'WA',
#   'Postal Code': 98055.0,
#   'Model Year': 2023,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 11.0,
#   'DOL Vehicle ID': 220654815,
#   'Vehicle Location': 'POINT (-122.197 47.43876)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033029308.0},
#  {'VIN (1-10)': '5YJ3E1EB6J',
#   'County': 'King',
#   'City': 'Seattle',
#   'State': 'WA',
#   'Postal Code': 98102.0,
#   'Model Year': 2018,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 215.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 43.0,
#   'DOL Vehicle ID': 213030597,
#   'Vehicle Location': 'POINT (-122.32427 47.63433)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033006100.0},
#  {'VIN (1-10)': '5YJ3E1EB7K',
#   'County': 'Clark',
#   'City': 'Vancouver',
#   'State': 'WA',
#   'Postal Code': 98685.0,
#   'Model Year': 2019,
#   'Make': 'TESLA',
#   'Model': 'MODEL 3',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 220.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 18.0,
#   'DOL Vehicle ID': 190072823,
#   'Vehicle Location': 'POINT (-122.70303 45.70954)',
#   'Electric Utility': 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)',
#   '2020 Census Tract': 53011040907.0},
#  {'VIN (1-10)': '1G1RB6S54J',
#   'County': 'Snohomish',
#   'City': 'Edmonds',
#   'State': 'WA',
#   'Postal Code': 98020.0,
#   'Model Year': 2018,
#   'Make': 'CHEVROLET',
#   'Model': 'VOLT',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 53.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 21.0,
#   'DOL Vehicle ID': 348460101,
#   'Vehicle Location': 'POINT (-122.37689 47.81116)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061050403.0},
#  {'VIN (1-10)': '7SAYGDEE0R',
#   'County': 'King',
#   'City': 'Redmond',
#   'State': 'WA',
#   'Postal Code': 98052.0,
#   'Model Year': 2024,
#   'Make': 'TESLA',
#   'Model': 'MODEL Y',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 45.0,
#   'DOL Vehicle ID': 269604506,
#   'Vehicle Location': 'POINT (-122.13158 47.67858)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033032321.0},
#  {'VIN (1-10)': '3GN7DLRPXR',
#   'County': 'King',
#   'City': 'Renton',
#   'State': 'WA',
#   'Postal Code': 98056.0,
#   'Model Year': 2024,
#   'Make': 'CHEVROLET',
#   'Model': 'EQUINOX',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 11.0,
#   'DOL Vehicle ID': 272342248,
#   'Vehicle Location': 'POINT (-122.1805 47.50006)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033025401.0},
#  {'VIN (1-10)': 'WB523CF07R',
#   'County': 'King',
#   'City': 'Seattle',
#   'State': 'WA',
#   'Postal Code': 98134.0,
#   'Model Year': 2024,
#   'Make': 'BMW',
#   'Model': 'IX',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 37.0,
#   'DOL Vehicle ID': 271117395,
#   'Vehicle Location': 'POINT (-122.32741 47.58616)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033009300.0},
#  {'VIN (1-10)': 'JTJCJMGA0R',
#   'County': 'King',
#   'City': 'Auburn',
#   'State': 'WA',
#   'Postal Code': 98092.0,
#   'Model Year': 2024,
#   'Make': 'LEXUS',
#   'Model': 'RX',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 37.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 47.0,
#   'DOL Vehicle ID': 274340524,
#   'Vehicle Location': 'POINT (-122.1821 47.3199)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033029602.0},
#  {'VIN (1-10)': 'WP0AA2Y13S',
#   'County': 'King',
#   'City': 'Bellevue',
#   'State': 'WA',
#   'Postal Code': 98006.0,
#   'Model Year': 2025,
#   'Make': 'PORSCHE',
#   'Model': 'TAYCAN',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 41.0,
#   'DOL Vehicle ID': 272038161,
#   'Vehicle Location': 'POINT (-122.12096 47.55584)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033024902.0},
#  {'VIN (1-10)': '1N4BZ1CP4K',
#   'County': 'King',
#   'City': 'Seattle',
#   'State': 'WA',
#   'Postal Code': 98125.0,
#   'Model Year': 2019,
#   'Make': 'NISSAN',
#   'Model': 'LEAF',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Clean Alternative Fuel Vehicle Eligible',
#   'Electric Range': 150.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 46.0,
#   'DOL Vehicle ID': 243974069,
#   'Vehicle Location': 'POINT (-122.30253 47.72656)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033000102.0},
#  {'VIN (1-10)': 'WBY33AW03P',
#   'County': 'Snohomish',
#   'City': 'Everett',
#   'State': 'WA',
#   'Postal Code': 98208.0,
#   'Model Year': 2023,
#   'Make': 'BMW',
#   'Model': 'I4',
#   'Electric Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Eligibility unknown as battery range has not been researched',
#   'Electric Range': 0.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 21.0,
#   'DOL Vehicle ID': 219612949,
#   'Vehicle Location': 'POINT (-122.18637 47.89251)',
#   'Electric Utility': 'PUGET SOUND ENERGY INC',
#   '2020 Census Tract': 53061041701.0},
#  {'VIN (1-10)': 'KNDCC3LD3K',
#   'County': 'King',
#   'City': 'Seattle',
#   'State': 'WA',
#   'Postal Code': 98101.0,
#   'Model Year': 2019,
#   'Make': 'KIA',
#   'Model': 'NIRO',
#   'Electric Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'Clean Alternative Fuel Vehicle (CAFV) Eligibility': 'Not eligible due to low battery range',
#   'Electric Range': 26.0,
#   'Base MSRP': 0.0,
#   'Legislative District': 43.0,
#   'DOL Vehicle ID': 233769280,
#   'Vehicle Location': 'POINT (-122.34223 47.61085)',
#   'Electric Utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)',
#   '2020 Census Tract': 53033008200.0},
#  ...]

# %%
len(EV_data)
# Out:
# 250659

# %%
DB_NAME = "Electric_Vehicle"
COLLECTION_NAME = "ev_data"
load_dotenv()
mongo_url=os.getenv("MONGO_URL")

# %%
client = pymongo.MongoClient(mongo_url, serverSelectionTimeoutMS=30000, socketTimeoutMS=30000)
data_base = client[DB_NAME]
collection=data_base[COLLECTION_NAME]
#use batch loading to inser the data into MongoDB because th dataset is large

BATCH_SIZE = 500
MAX_RETRIES = 3

for i in range(0, len(EV_data), BATCH_SIZE):
    batch = EV_data[i:i + BATCH_SIZE]
    for attempt in range(MAX_RETRIES):
        try:
            collection.insert_many(batch)
            break
        except AutoReconnect as e:
            print(f"Retrying batch insert ({i}-{i+BATCH_SIZE}) after error : {e}") 
            time.sleep(5)
    else:
        print(f"Failed to insert batch {i} - {i+BATCH_SIZE} after retries ")
